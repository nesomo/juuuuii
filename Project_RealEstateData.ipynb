# %%
# Importing the libraries
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

r= requests.get("https://www.car.org/en/marketdata/data/haitraditional/", headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})

# Storing the content (HTML code) of website
c= r.content
c
# Out:
# b'\n<!DOCTYPE html>\n<!--[if IE 9]><html lang="en" class="ie9 no-js"><![endif]-->\n<!--[if !IE]><!-->\n<html lang="en">\n<!--<![endif]-->\n<head>\n<meta charset="utf-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=10, user-scalable=yes" />\n<meta name="apple-mobile-web-app-capable" content="yes" />\n<meta name="referrer" content="always">\n<link rel="manifest" href="/manifest.json">\n<title>Housing Affordability Index - Traditional </title>\n<meta name="keywords" content="Housing,Data,2010,2011,Housing Opportunity,Market Analysis,Market Stats" />\n<meta name="description" content="C.A.R.\xe2\x80\x99s index tracking historical affordability trends throughout California under traditional assumptions" />\n<meta name="robots" content="index, follow" />\n\n<meta property="og:url" content="https://www.car.org/en/marketdata/data/haitraditional/">\n<meta property="og:title" content="Housing Af
# ...

# %%
all= soup.find_all("a",{"class":"subLink"})
print(all)
# Out:
# [<a class="subLink" href="/en/marketdata/data/countysalesactivity">
# Current Sales &amp; Price Statistics
# </a>, <a class="subLink" href="/en/marketdata/data/haitraditional">
# Housing Affordability Index - Traditional
# </a>, <a class="subLink" href="/en/marketdata/data/housingdata">
# Historical Housing Data
# </a>, <a class="subLink" href="/en/marketdata/interactive/buyersguide">
# Buyer's Guide
# </a>, <a class="subLink" href="/en/marketdata/interactive/housingmarketoverview">
# Housing Market Overview
# </a>, <a class="subLink" href="/en/marketdata/interactive/marketupdatevideos">
# Market Update Videos
# </a>, <a class="subLink" href="/en/marketdata/interactive/View-All-Shareable-Reports">
# All Shareable Reports
# </a>, <a class="subLink" href="/en/marketdata/interactive/View-All-Interactive-Dashboards">
# All Interactive Dashboards
# </a>, <a class="subLink" href="/en/advocacy/PACSnRAF/raf">
# REALTOR® Action Fund
# </a>]

# %%
 for tag in soup.findAll('a'):
        print (tag.contents)
# Out:
# ['\n', <h6>Housing Market Forecast</h6>, '\n']
# ['\n', <h6>Data &amp; Statistics</h6>, '\n']
# ['\nCurrent Sales & Price Statistics\n']
# ['\nHousing Affordability Index - Traditional\n']
# ['\nHistorical Housing Data\n']
# ['\n', <h6>Housing Matters Podcast</h6>, '\n']
# ['\n', <h6>Market Minute</h6>, '\n']
# ['\n', <h6>Shareable and Interactive Reports</h6>, '\n']
# ["\nBuyer's Guide\n"]
# ['\nHousing Market Overview\n']
# ['\nMarket Update Videos\n']
# ['\nAll Shareable Reports\n']
# ['\nAll Interactive Dashboards\n']
# ['\n', <h6>Speeches &amp; Presentations</h6>, '\n']
# ['\n', <h6>Surveys &amp; Reports</h6>, '\n']
# ['\n', <h6>Stay Connected</h6>, '\n']
# ['\n', <h6>Model MLS Rules/Materials</h6>, '\n']
# ['\n', <h6>Code of Ethics Violators</h6>, '\n']
# ['\n', <h6>Statewide MLS Initiative</h6>, '\n']
# ['\n', <h6>NAR Code of Ethics</h6>, '\n']
# ['\n', <h6>Online Training for Professional Standards Volunteers</h6>, '\n']
# ...

# %%
content_list=soup.findAll('a',attrs={'class':'subLink'})
content_list
for tag in content_list:
    if contents
    print (tag.contents)
print (tag.contents)
# Out:
# ['\nCurrent Sales & Price Statistics\n']
# ['\nHousing Affordability Index - Traditional\n']
# ['\nHistorical Housing Data\n']
# ["\nBuyer's Guide\n"]
# ['\nHousing Market Overview\n']
# ['\nMarket Update Videos\n']
# ['\nAll Shareable Reports\n']
# ['\nAll Interactive Dashboards\n']
# ['\nREALTOR® Action Fund\n']
# ['\nREALTOR® Action Fund\n']

# %%
all= soup.find_all("a",{"class":"subLink"})
all
for all in
# Out:
# [<a class="subLink" href="/en/marketdata/data/countysalesactivity">
#  Current Sales &amp; Price Statistics
#  </a>, <a class="subLink" href="/en/marketdata/data/haitraditional">
#  Housing Affordability Index - Traditional
#  </a>, <a class="subLink" href="/en/marketdata/data/housingdata">
#  Historical Housing Data
#  </a>, <a class="subLink" href="/en/marketdata/interactive/buyersguide">
#  Buyer's Guide
#  </a>, <a class="subLink" href="/en/marketdata/interactive/housingmarketoverview">
#  Housing Market Overview
#  </a>, <a class="subLink" href="/en/marketdata/interactive/marketupdatevideos">
#  Market Update Videos
#  </a>, <a class="subLink" href="/en/marketdata/interactive/View-All-Shareable-Reports">
#  All Shareable Reports
#  </a>, <a class="subLink" href="/en/marketdata/interactive/View-All-Interactive-Dashboards">
#  All Interactive Dashboards
#  </a>, <a class="subLink" href="/en/advocacy/PACSnRAF/raf">
#  REALTOR® Action Fund
#  </a>]

# %%
all[2].text.replace("\n","").replace(" ","")
# Out:
# 'HistoricalHousingData'

# %%
#import webbrowser
webbrowser.open("https://www.car.org/en/marketdata/data/haitraditional")
webbrowser.open("https://www.cdc.gov/nchs/covid19/pulse/reduced-access-to-care.htm", "https://www.huduser.gov/portal/home.html")
webbrowser.open("https://www.census.gov/data/experimental-data-products/household-pulse-survey.html")
webbrowser.open("https://www.nlc.org/wp-content/uploads/2021/02/UnlockingHomelessnessReportPart1.pdf")
webbrowser.open("https://www.usich.gov/tools-for-action/map/#fn[]=1400&fn[]=2800&fn[]=6200&fn[]=10000&fn[]=13200")
webbrowser.open("https://www.huduser.gov/portal/datasets/ahar/2020-ahar-part-1-pit-estimates-of-homelessness-in-the-us.html")
webbrowser.open("https://www.hud.gov/sites/dfiles/CPD/documents/FY-2021_CoC-Names-Numbers_Final.pdf")
webbrowser.open("https://data.bls.gov/timeseries/LASST060000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true")
webbrowser.open(":Housing Affordability Advances in January 2021 as Incomes Rise (nar.realtor)")
webbrowser.open("American Housing Survey: Housing Affordability Data System | HUD USER")
# Out:
# True

# %%
project = pd.read_csv('dataset_interpolate.csv')
project.head()
# Out:
#    Unnamed: 0  Year Period  Week  Overall Number of Homeless  \
# 0           0  2011    Jan     1                 129738.8333
# 1           1  2011    Feb     2                 129319.6667
# 2           2  2011    Mar     3                 128900.5000
# 3           3  2011    Apr     4                 128481.3333
# 4           4  2011    May     5                 128062.1667
#
#    labor force participation rate  employment-population ratio  labor force  \
# 0                            63.8                         55.9    1836380.5
# 1                            63.7                         55.9    1835912.1
# 2                            63.6                         55.9    1835466.9
# 3                            63.6                         55.9    1835242.8
# 4                            63.5                         55.9    1835863.9
#
#    employment  unemployment  unemployment rate  Poverty Rate (CA)  \
# 0   1611338.6      225041.9               12.3           0.162333
# ...

# %%
p=project.replace(np.nan,0)
p
# Out:
#      Unnamed: 0  Year Period  Week  Overall Number of Homeless  \
# 0             0  2011    Jan     1                 129738.8333
# 1             1  2011    Feb     2                 129319.6667
# 2             2  2011    Mar     3                 128900.5000
# 3             3  2011    Apr     4                 128481.3333
# 4             4  2011    May     5                 128062.1667
# ..          ...   ...    ...   ...                         ...
# 117         117  2020    Oct   118                 159836.3333
# 118         118  2020    Nov   119                 160692.1667
# 119         119  2020    Dec   120                 161548.0000
# 120         120  2021    Jan   121                 161548.0000
# 121         121  2021    Feb   122                 161548.0000
#
#      labor force participation rate  employment-population ratio  labor force  \
# 0                              63.8                         55.9    1836380.5
# ...

# %%
p.shape
p.describe()
# Out:
#        Unnamed: 0         Year        Week  Overall Number of Homeless  \
# count  122.000000   122.000000  122.000000                  122.000000
# mean    60.500000  2015.590164   61.500000               127719.106557
# std     35.362409     2.945101   35.362409                13453.989086
# min      0.000000  2011.000000    1.000000               113952.000000
# 25%     30.250000  2013.000000   31.250000               117591.083325
# 50%     60.500000  2016.000000   61.500000               123586.250000
# 75%     90.750000  2018.000000   91.750000               130979.500000
# max    121.000000  2021.000000  122.000000               161548.000000
#
#        labor force participation rate  employment-population ratio  \
# count                      122.000000                   122.000000
# mean                        61.867213                    57.673770
# std                          5.166971                     1.981268
# ...

# %%
# Import matplotlib and seaborn libraries to visualize the data
import matplotlib.pyplot as plt 
import seaborn as sns

# Using pairplot we'll visualize the data for correlation
sns.pairplot(project, x_vars=['Year', 'employment-population ratio','unemployment rate'], 
             y_vars='Overall Number of Homeless', height=4, aspect=1, kind='scatter')
plt.show()

# %%
house_data_nadrop = p.select_dtypes(exclude=['object'])
#Select SalePrice and store into target variable
target = house_data_nadrop['Overall Number of Homeless']

#drop Saleprice and store rest of the data to features
features = house_data_nadrop.drop('Overall Number of Homeless', axis = 1)

#Drop Id as we do not need it for modelling purpose
features = features.drop(['Year'], axis = 1)

# %%
#Split the data into train and validation
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=10)

# %%
from sklearn.ensemble import RandomForestRegressor

#create the model
regressor_model = RandomForestRegressor(random_state=0)

#fit the model
regressor_model.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regressor_model.predict(X_test)
# Out:
# C:\Users\mou_1\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.9927156511777382

# %%
import seaborn as sns
colors = np.array('b g r c m y k'.split()) #Different colors for plotting

fig,axes = plt.subplots(nrows =8,ncols=2, sharey=True,figsize = (15,40))
plt.tight_layout()
row = 0
iteration = 0
for j in range(0,len(house_data_nadrop.columns[:-1])):
    iteration+=1
    if(j%2==0):
        k = 0
    else:
        k = 1
    sns.distplot(house_data_nadrop[house_data_nadrop.columns[j]],kde=False,hist_kws=dict(edgecolor="w", linewidth=2),
                 color = np.random.choice(colors) ,ax=axes[row][k])
    if(iteration%2==0):
        row+=1
        plt.ylim(0,100)

# %%
plt.figure(figsize= (8,8), dpi=100)
sns.heatmap(house_data_nadrop.corr(),cmap="YlGnBu", annot = True)

# %%
target = house_data_nadrop['Overall Number of Homeless']

#drop Saleprice and store rest of the data to features
features = house_data_nadrop[['Year','Week', 'labor force', 'employment', 'unemployment', 'Poverty Threshold (2 People)', 'SNAP Beneficiaries', 'Median House Prices']].copy()

features
# Out:
#      Year  Week  labor force  employment  unemployment  \
# 0    2011     1    1836380.5   1611338.6      225041.9
# 1    2011     2    1835912.1   1612779.6      223132.5
# 2    2011     3    1835466.9   1613980.5      221486.4
# 3    2011     4    1835242.8   1614758.5      220484.3
# 4    2011     5    1835863.9   1615506.7      220357.2
# ..    ...   ...          ...         ...           ...
# 117  2020   118    1890463.8   1705026.0      185437.8
# 118  2020   119    1860462.6   1698390.3      162072.3
# 119  2020   120    1870547.5   1695701.9      174845.6
# 120  2021   121    1866852.3   1698868.3      167984.0
# 121  2021   122    1894453.6   1733433.3      161020.3
#
#      Poverty Threshold (2 People)  SNAP Beneficiaries  Median House Prices
# 0                     14400.33333          3602170.00             279220.0
# 1                     14423.66667          3619055.00             271370.0
# 2                     14447.00000          3669962.00             286550.0
# ...

# %%
#Split the data into train and validation
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=10)

# %%
from sklearn.ensemble import RandomForestRegressor

#create the model
regressor_model = RandomForestRegressor(random_state=0)

#fit the model
regressor_model.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regressor_model.predict(X_test)
# Out:
# C:\Users\mou_1\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.9911692102580577

# %%
#Load the data and have a look at the sample
test_data = pd.read_excel('Homeless_test.csv')
test_data.head()
# Out:
#    Unnamed: 0  Year Period  Week  Overall Number of Homeless  \
# 0           1  2020    Mar   111                 153845.5000
# 1           2  2020    Apr   112                 154701.3333
# 2           3  2020    May   113                 155557.1667
# 3           4  2020    Jun   114                 156413.0000
# 4           5  2020    Jul   115                 157268.8333
#
#    labor force participation rate  employment-population ratio  labor force  \
# 0                            61.7                         58.9    1916866.5
# 1                            59.8                         50.3    1859086.4
# 2                            59.2                         50.0    1839252.8
# 3                            60.5                         52.0    1881314.2
# 4                            60.3                         52.4    1873153.9
#
#    employment  unemployment  unemployment rate  Poverty Rate (CA)  \
# 0   1830457.4       86409.1                4.5              0.118
# ...

# %%
#Drop NA values
test_data_nadrop = test_data.dropna(axis=1)
test_data_nadrop.head()
# Out:
#    Unnamed: 0  Year Period  Week  Overall Number of Homeless  \
# 0           1  2020    Mar   111                 153845.5000
# 1           2  2020    Apr   112                 154701.3333
# 2           3  2020    May   113                 155557.1667
# 3           4  2020    Jun   114                 156413.0000
# 4           5  2020    Jul   115                 157268.8333
#
#    labor force participation rate  employment-population ratio  labor force  \
# 0                            61.7                         58.9    1916866.5
# 1                            59.8                         50.3    1859086.4
# 2                            59.2                         50.0    1839252.8
# 3                            60.5                         52.0    1881314.2
# 4                            60.3                         52.4    1873153.9
#
#    employment  unemployment  unemployment rate  Poverty Rate (CA)  \
# 0   1830457.4       86409.1                4.5              0.118
# ...

# %%
test_data_nadrop.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Period', 'Week', 'Overall Number of Homeless',
#        'labor force participation rate', 'employment-population ratio',
#        'labor force', 'employment', 'unemployment', 'unemployment rate',
#        'Poverty Rate (CA)', 'Poverty Threshold (single)',
#        'Poverty Threshold (2 People)', 'SNAP Beneficiaries',
#        'House Affordability Index (HAI)', 'California Median Weekly Wages',
#        'Median House Prices'],
#       dtype='object')

# %%
features = test_data_nadrop[['Year','Week', 'labor force', 'employment', 'unemployment', 'Poverty Threshold (2 People)', 'SNAP Beneficiaries', 'Median House Prices']].copy()

features
# Out:
#     Year  Week  labor force  employment  unemployment  \
# 0   2020   111    1916866.5   1830457.4       86409.1
# 1   2020   112    1859086.4   1562442.9      296643.5
# 2   2020   113    1839252.8   1552931.9      286320.9
# 3   2020   114    1881314.2   1616103.6      265210.6
# 4   2020   115    1873153.9   1626804.5      246349.4
# 5   2020   116    1866666.3   1636534.3      230132.0
# 6   2020   117    1838555.8   1643550.3      195005.5
# 7   2020   118    1890463.8   1705026.0      185437.8
# 8   2020   119    1860462.6   1698390.3      162072.3
# 9   2020   120    1870547.5   1695701.9      174845.6
# 10  2021   121    1866852.3   1698868.3      167984.0
# 11  2021   122    1894453.6   1733433.3      161020.3
#
#     Poverty Threshold (2 People)  SNAP Beneficiaries  Median House Prices
# 0                    16512.62500          4100000.00               612440
# 1                    16509.83333          4300000.00               606410
# ...

# %%
test_pred = regressor_model.predict(features)

# %%
test_pred
# Out:
# array([152589.88333, 156156.25002, 156327.41669, 156498.58333,
#        157439.99998, 158894.91668, 159494.     , 160007.49997,
#        160777.75003, 161205.66667, 160948.91667, 160948.91667])

# %%
columns = ['Year', 'Overall Number of Homeless']
dataframe = pd.DataFrame(columns=columns)

# %%
dataframe["Year"] = test_data_nadrop["Year"]
dataframe["Overall Number of Homeless"] = test_pred
dataframe.head()
# Out:
#    Year  Overall Number of Homeless
# 0  2020                152589.88333
# 1  2020                156156.25002
# 2  2020                156327.41669
# 3  2020                156498.58333
# 4  2020                157439.99998

# %%
train_data = pd.read_csv('Homeless_train.csv')
train_data.head()
# Out:
#    Unnamed: 0  Year Period  Week  Overall Number of Homeless  \
# 0           0  2011    Jan     1                 129738.8333
# 1           1  2011    Feb     2                 129319.6667
# 2           2  2011    Mar     3                 128900.5000
# 3           3  2011    Apr     4                 128481.3333
# 4           4  2011    May     5                 128062.1667
#
#    labor force participation rate  employment-population ratio  labor force  \
# 0                            63.8                         55.9    1836380.5
# 1                            63.7                         55.9    1835912.1
# 2                            63.6                         55.9    1835466.9
# 3                            63.6                         55.9    1835242.8
# 4                            63.5                         55.9    1835863.9
#
#    employment  unemployment  unemployment rate  Poverty Rate (CA)  \
# 0   1611338.6      225041.9               12.3           0.162333
# ...

# %%
sns.pairplot(project, x_vars=['Year', 'employment-population ratio','House Affordability Index (HAI)'], 
             y_vars='Overall Number of Homeless', height=4, aspect=1, kind='scatter')
plt.show()

# %%
# Visualizing the data using heatmap
sns.heatmap(project.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %%
# Creating X and y
X = project['labor force participation rate']
y = project['House Affordability Index (HAI)']

# %%
# Splitting the varaibles as training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, 
                                                    test_size = 0.3, random_state = 100)

# %%
# Take a look at the train dataset
X_train
y_train
# Out:
# 82     0.296667
# 104    0.310000
# 20     0.483333
# 43     0.296667
# 6      0.520000
#          ...
# 87     0.260000
# 103    0.310000
# 67     0.300000
# 24     0.440000
# 8      0.540000
# Name: House Affordability Index (HAI), Length: 85, dtype: float64

# %%
# Importing Statsmodels.api library from Stamodel package
import statsmodels.api as sm

# Adding a constant to get an intercept
X_train_sm = sm.add_constant(X_train)

# %%
# %matplotlib inline

#imports
from numpy import *
import matplotlib.pyplot as plt
points = genfromtxt('RealEstate.csv', delimiter=',')

#Extract columns
x = X_train
y = y_train

#Plot the dataset
plt.scatter(x,y)
plt.xlabel('Year')
plt.ylabel('Homelessness')
plt.title('Dataset')
plt.show()

# %%
def gradient_descent_runner(points, starting_b, starting_m, learning_rate, num_iterations):
    b = starting_b
    m = starting_m
    cost_graph = []

    #For every iteration, optimize b, m and compute its cost
    for i in range(num_iterations):
        cost_graph.append(compute_cost(b, m, points))
        b, m = step_gradient(b, m, array(points), learning_rate)

    return [b, m, cost_graph]

def step_gradient(b_current, m_current, points, learning_rate):
    m_gradient = 0
    b_gradient = 0
    N = float(len(points))

    #Calculate Gradient
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        m_gradient += - (2/N) * x * (y - (m_current * x + b_current))
        b_gradient += - (2/N) * (y - (m_current * x + b_current))
    
    #Update current m and b
    m_updated = m_current - learning_rate * m_gradient
    b_updated = b_current - learning_rate * b_gradient

    #Return updated parameters
    return b_updated, m_updated

# %%
b, m, cost_graph = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations)

#Print optimized parameters
print ('Optimized b:', b)
print ('Optimized m:', m)

#Print error with optimized parameters
print ('Minimized cost:', compute_cost(b, m, points))
# Out:
# Optimized b: nan
# Optimized m: nan
# Minimized cost: nan

# %%
plt.plot(cost_graph)
plt.xlabel('No. of iterations')
plt.ylabel('Cost')
plt.title('Cost per iteration')
plt.show()

# %%
#Plot dataset
plt.scatter(x, y)
#Predict y values
pred = m * x + b
#Plot predictions as line of best fit
plt.plot(x, pred, c='r')
plt.xlabel('Hours of study')
plt.ylabel('Test scores')
plt.title('Line of best fit')
plt.show()

# %%
import statsmodels.formula.api as smf
y_train = project["Overall Number of Homeless"]
X_train = project["unemployment rate"]
X_train = sm.add_constant(X_train)

model = sm.OLS(y_train, X_train)
results = model.fit()
print(results.t_test([1, 0]))
print(results.summary())
# Out:
#                              Test for Constraints
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0          1.239e+05   3274.669     37.823      0.000    1.17e+05     1.3e+05
# ...
#                                 OLS Regression Results
# ...
# Dep. Variable:     Overall Number of Homeless   R-squared:                       0.013
# Model:                                    OLS   Adj. R-squared:                  0.005
# Method:                         Least Squares   F-statistic:                     1.611
# Date:                        Sat, 17 Apr 2021   Prob (F-statistic):              0.207
# Time:                                15:16:33   Log-Likelihood:                -1331.7
# No. Observations:                         122   AIC:                             2667.
# Df Residuals:                             120   BIC:                             2673.
# ...

# %%
X_train = sm.add_constant(X_train)
model = sm.OLS(y_train,X_train).fit()

print(model.summary())
# Out:
#                                 OLS Regression Results
# ...
# Dep. Variable:     Overall Number of Homeless   R-squared:                       0.013
# Model:                                    OLS   Adj. R-squared:                  0.005
# Method:                         Least Squares   F-statistic:                     1.611
# Date:                        Sat, 17 Apr 2021   Prob (F-statistic):              0.207
# Time:                                15:19:13   Log-Likelihood:                -1331.7
# No. Observations:                         122   AIC:                             2667.
# Df Residuals:                             120   BIC:                             2673.
# Df Model:                                   1
# Covariance Type:                    nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
print(model.rsquared)
print(model.rsquared_adj)
# Out:
# 0.013249603093503315
# 0.00502668311928256

# %%
homeless_pred = model.predict()

# Plot regression against actual data
plt.figure(figsize=(12, 6))
plt.plot(project['Median House Prices'], project['Overall Number of Homeless'], 'o')           # scatter plot showing actual data
plt.plot(project['Median House Prices'], sales_pred, 'r', linewidth=2)   # regression line
plt.xlabel('Median House Prices')
plt.ylabel('Overall Number of Homeless')
plt.title('Median House Prices vs Overall Number of Homeless')

plt.show()

# %%
from sklearn.linear_model import LinearRegression

# Build linear regression model using TV and Radio as predictors
# Split data into predictors X and output Y
predictors = ['Median House Prices', 'unemployment rate']
X = project[predictors]
y = project['Overall Number of Homeless']

# Initialise and fit model
lm = LinearRegression()
model = lm.fit(X, y)

# %%
print(f'alpha = {model.intercept_}')
print(f'betas = {model.coef_}')
# Out:
# alpha = 57650.812393192624
# betas = [1.04856227e-01 2.60910717e+03]

# %%
model.predict(X)
# Out:
# array([119020.78609955, 117936.75400486, 119267.56080669, 119802.50884931,
#        119667.24431711, 120040.53248349, 120171.60276663, 119847.77831413,
#        118710.26954392, 117008.81556251, 117005.85116314, 117431.93001761,
#        115340.22958616, 114537.39346594, 117349.63746093, 118857.65128557,
#        119011.97122596, 119226.05921546, 120091.48565901, 120574.1868758 ,
#        120413.93813666, 119488.42023142, 119715.09096811, 121580.66452514,
#        118259.00055673, 117373.32801756, 121916.92959966, 124154.7427608 ,
#        125416.34445313, 126345.55190743, 126630.94213096, 127114.51062259,
#        125519.8287048 , 124919.36510174, 124191.84417719, 125577.1762168 ,
#        122332.23858117, 121404.44226398, 124356.32632765, 125052.93424652,
#        126548.36532397, 125472.7217274 , 125951.04740771, 127420.26442853,
#        125180.71671771, 123669.91978112, 122797.69726398, 123181.83362785,
# ...

# %%
new_X = [[48300, 7]]
print(model.predict(new_X))
#This means that if we can stick the medium homeprice around 400000 and unemployement rate at 6 percent then we should expect to see, on average, 83797 homelessness.
# Out:
# [80979.11829475]

# %%
# importing libreries and changing their name

import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import matplotlib

plt.style.use('fivethirtyeight')
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %%
# read the excel file
Project = pd.read_csv("dataset_interpolate.csv")
Project.head()
# Out:
#    Unnamed: 0  Year Period  Week  Overall Number of Homeless  \
# 0           0  2011    Jan     1                 129738.8333
# 1           1  2011    Feb     2                 129319.6667
# 2           2  2011    Mar     3                 128900.5000
# 3           3  2011    Apr     4                 128481.3333
# 4           4  2011    May     5                 128062.1667
#
#    labor force participation rate  employment-population ratio  labor force  \
# 0                            63.8                         55.9    1836380.5
# 1                            63.7                         55.9    1835912.1
# 2                            63.6                         55.9    1835466.9
# 3                            63.6                         55.9    1835242.8
# 4                            63.5                         55.9    1835863.9
#
#    employment  unemployment  unemployment rate  Poverty Rate (CA)  \
# 0   1611338.6      225041.9               12.3           0.162333
# ...

# %%
Project.describe()
# Out:
#        Unnamed: 0         Year        Week  Overall Number of Homeless  \
# count  122.000000   122.000000  122.000000                  122.000000
# mean    60.500000  2015.590164   61.500000               127719.106557
# std     35.362409     2.945101   35.362409                13453.989086
# min      0.000000  2011.000000    1.000000               113952.000000
# 25%     30.250000  2013.000000   31.250000               117591.083325
# 50%     60.500000  2016.000000   61.500000               123586.250000
# 75%     90.750000  2018.000000   91.750000               130979.500000
# max    121.000000  2021.000000  122.000000               161548.000000
#
#        labor force participation rate  employment-population ratio  \
# count                      122.000000                   122.000000
# mean                        61.867213                    57.673770
# std                          5.166971                     1.981268
# ...

# %%
# Remove columns which are not required in predictions

cols = ['Period', 'Week', 'labor force', 'employment', 'unemployment', 'Poverty Threshold (2 People)', 'SNAP Beneficiaries', 'Median House Prices']
Project.drop(cols, axis = 1, inplace = True)
Project.head()
# Out:
#    Unnamed: 0  Year  Overall Number of Homeless  \
# 0           0  2011                 129738.8333
# 1           1  2011                 129319.6667
# 2           2  2011                 128900.5000
# 3           3  2011                 128481.3333
# 4           4  2011                 128062.1667
#
#    labor force participation rate  employment-population ratio  \
# 0                            63.8                         55.9
# 1                            63.7                         55.9
# 2                            63.6                         55.9
# 3                            63.6                         55.9
# 4                            63.5                         55.9
#
#    unemployment rate  Poverty Rate (CA)  Poverty Threshold (single)  \
# 0               12.3           0.162333                 11267.66667
# 1               12.2           0.162667                 11287.33333
# 2               12.1           0.163000                 11307.00000
# ...

# %%
# Sort the Order Date 
Project = Project.sort_values('Year')

#print the sorted values
print(Project.head(1))

#check any missing values
Project.isnull().sum()
# Out:
#    Unnamed: 0  Year  Overall Number of Homeless  \
# 0           0  2011                 129738.8333
#
#    labor force participation rate  employment-population ratio  \
# 0                            63.8                         55.9
#
#    unemployment rate  Poverty Rate (CA)  Poverty Threshold (single)  \
# 0               12.3           0.162333                 11267.66667
#
#    House Affordability Index (HAI)  California Median Weekly Wages
# 0                             0.53                          1066.0
# Unnamed: 0                         0
# Year                               0
# Overall Number of Homeless         0
# labor force participation rate     0
# employment-population ratio        0
# unemployment rate                  0
# Poverty Rate (CA)                  0
# Poverty Threshold (single)         0
# House Affordability Index (HAI)    0
# California Median Weekly Wages     0
# dtype: int64

# %%
# grouping sales according to year
Project.groupby('Year')['Overall Number of Homeless'].sum().reset_index()

# min and max values of Order Date
print(Project['Year'].min())
print(Project['Year'].max())
# Out:
# 2011
# 2021

# %%
#set 'year' as index
Project = Project.set_index('Year')
Project.index
# Out:
# Int64Index([2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011,
#             ...
#             2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2021, 2021],
#            dtype='int64', name='Year', length=122)
